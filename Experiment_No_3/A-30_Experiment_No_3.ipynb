# %% [markdown]
# #### Name:- Mayur Chaudhari
#
# #### Div :- A
#
# #### Roll No :- 30
#
# #### Experiment No :- 3
#
# Title :- Apply a-priori algorithm to find frequently occurring items from given data and generate strong association rules using support and confidence thresholds.  For Example: Market Basket Analysis

# %%
import pandas as pd

# %%
from mlxtend.frequent_patterns import apriori
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import association_rules

# %%
basket = [['Milk','Onion','Nutmeg','Kidney Beans','Eggs','Yogurt'],
          ['Eggs','Milk','Onion','Apple','Ice cream','Eggs'],
          ['Dill','Onion','Nutmeg','Kidney Beans','Eggs','Yogurt'],
          ['Milk','Apple','Kidney Beans','Eggs'],
          ['Ice cream','Onion','Kidney Beans','Eggs'],
          ['Milk','Unicorn','Corn','Kidney Beans','Yogurt'],
          ['Onion','Onion','Apple','Ice cream','Yogurt'],
          ['Yogurt','Eggs','Onion','Kidney Beans','Ice cream','Eggs'],
          ['Kidney Beans','Onion','Yogurt','Kidney Beans','Eggs'],
          ['Corn','Onion','Onion','Kidney Beans','Ice cream','Eggs']
         ]

# %%
basket
# Out:
# [['Milk', 'Onion', 'Nutmeg', 'Kidney Beans', 'Eggs', 'Yogurt'],
#  ['Eggs', 'Milk', 'Onion', 'Apple', 'Ice cream', 'Eggs'],
#  ['Dill', 'Onion', 'Nutmeg', 'Kidney Beans', 'Eggs', 'Yogurt'],
#  ['Milk', 'Apple', 'Kidney Beans', 'Eggs'],
#  ['Ice cream', 'Onion', 'Kidney Beans', 'Eggs'],
#  ['Milk', 'Unicorn', 'Corn', 'Kidney Beans', 'Yogurt'],
#  ['Onion', 'Onion', 'Apple', 'Ice cream', 'Yogurt'],
#  ['Yogurt', 'Eggs', 'Onion', 'Kidney Beans', 'Ice cream', 'Eggs'],
#  ['Kidney Beans', 'Onion', 'Yogurt', 'Kidney Beans', 'Eggs'],
#  ['Corn', 'Onion', 'Onion', 'Kidney Beans', 'Ice cream', 'Eggs']]

# %%
TE = TransactionEncoder()
TE_ary =TE.fit(basket).transform(basket)

# %%
df = pd.DataFrame(TE_ary,columns=TE.columns_)

# %%
df.head()
# Out:
#    Apple   Corn   Dill  Eggs  Ice cream  Kidney Beans   Milk  Nutmeg  Onion  \
# 0  False  False  False  True      False          True   True    True   True
# 1   True  False  False  True       True         False   True   False   True
# 2  False  False   True  True      False          True  False    True   True
# 3   True  False  False  True      False          True   True   False  False
# 4  False  False  False  True       True          True  False   False   True
#
#    Unicorn  Yogurt
# 0    False    True
# 1    False   False
# 2    False    True
# 3    False   False
# 4    False   False

# %%
frequent_itemsets = apriori(df,min_support=0.6,use_colnames=True)
frequent_itemsets.head()
# Out:
#    support              itemsets
# 0      0.8                (Eggs)
# 1      0.8        (Kidney Beans)
# 2      0.8               (Onion)
# 3      0.6              (Yogurt)
# 4      0.7  (Eggs, Kidney Beans)

# %% [markdown]
# ###### Association Rule Mining

# %%
result1=association_rules(frequent_itemsets,metric='confidence',min_threshold=0.7)
result1
# Out:
#               antecedents            consequents  antecedent support  \
# 0                  (Eggs)         (Kidney Beans)                 0.8
# 1          (Kidney Beans)                 (Eggs)                 0.8
# 2                 (Onion)                 (Eggs)                 0.8
# 3                  (Eggs)                (Onion)                 0.8
# 4                 (Onion)         (Kidney Beans)                 0.8
# 5          (Kidney Beans)                (Onion)                 0.8
# 6   (Onion, Kidney Beans)                 (Eggs)                 0.6
# 7           (Onion, Eggs)         (Kidney Beans)                 0.7
# 8    (Kidney Beans, Eggs)                (Onion)                 0.7
# 9                 (Onion)   (Kidney Beans, Eggs)                 0.8
# 10         (Kidney Beans)          (Onion, Eggs)                 0.8
# 11                 (Eggs)  (Onion, Kidney Beans)                 0.8
#
# ...

# %%
result2 = result1[['antecedents','consequents','support','confidence','lift']]

# %%
result2
# Out:
#               antecedents            consequents  support  confidence  \
# 0                  (Eggs)         (Kidney Beans)      0.7    0.875000
# 1          (Kidney Beans)                 (Eggs)      0.7    0.875000
# 2                 (Onion)                 (Eggs)      0.7    0.875000
# 3                  (Eggs)                (Onion)      0.7    0.875000
# 4                 (Onion)         (Kidney Beans)      0.6    0.750000
# 5          (Kidney Beans)                (Onion)      0.6    0.750000
# 6   (Onion, Kidney Beans)                 (Eggs)      0.6    1.000000
# 7           (Onion, Eggs)         (Kidney Beans)      0.6    0.857143
# 8    (Kidney Beans, Eggs)                (Onion)      0.6    0.857143
# 9                 (Onion)   (Kidney Beans, Eggs)      0.6    0.750000
# 10         (Kidney Beans)          (Onion, Eggs)      0.6    0.750000
# 11                 (Eggs)  (Onion, Kidney Beans)      0.6    0.750000
#
#         lift
# 0   1.093750
# 1   1.093750
# ...

# %%
result3=result2[result2['confidence']>=1]

# %%
result3
# Out:
#              antecedents consequents  support  confidence  lift
# 6  (Onion, Kidney Beans)      (Eggs)      0.6         1.0  1.25
